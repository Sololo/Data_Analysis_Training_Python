# %% [markdown]
# <a href="https://colab.research.google.com/github/Sololo/Data_Analysis_Training_Python/blob/main/Python_Programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Loading Data

# %%
# Load the CSV
sales = pd.read_csv("Data/1000_Sales_Records.csv", parse_dates=['Order Date'])

# Show first 5 rows
sales.head()
# Out:
#                          Region Country   Item Type Sales Channel  \
# 0  Middle East and North Africa   Libya   Cosmetics       Offline
# 1                 North America  Canada  Vegetables        Online
# 2  Middle East and North Africa   Libya   Baby Food       Offline
# 3                          Asia   Japan      Cereal       Offline
# 4            Sub-Saharan Africa    Chad      Fruits       Offline
#
#   Order Priority Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M 2014-10-18  686800706  10/31/2014        8446      437.20
# 1              M 2011-11-07  185941302   12/8/2011        3018      154.06
# 2              C 2016-10-31  246222341   12/9/2016        1517      255.28
# 3              C 2010-04-10  161442649   5/12/2010        3322      205.70
# 4              H 2011-08-16  645713555   8/31/2011        9845        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0     263.33     3692591.20  2224085.18    1468506.02
# ...

# %%
sales.shape
# Out:
# (1000, 14)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          1000 non-null   object
#  1   Country         1000 non-null   object
#  2   Item Type       1000 non-null   object
#  3   Sales Channel   1000 non-null   object
#  4   Order Priority  1000 non-null   object
#  5   Order Date      1000 non-null   datetime64[ns]
#  6   Order ID        1000 non-null   int64
#  7   Ship Date       1000 non-null   object
#  8   Units Sold      1000 non-null   int64
#  9   Unit Price      1000 non-null   float64
#  10  Unit Cost       1000 non-null   float64
#  11  Total Revenue   1000 non-null   float64
#  12  Total Cost      1000 non-null   float64
#  13  Total Profit    1000 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(6)
# memory usage: 109.5+ KB

# %%
sales.describe()
# Out:
#                           Order Date      Order ID   Units Sold  Unit Price  \
# count                           1000  1.000000e+03  1000.000000  1000.00000
# mean   2013-09-19 23:29:45.600000256  5.496813e+08  5053.988000   262.10684
# min              2010-01-01 00:00:00  1.029280e+08    13.000000     9.33000
# 25%              2011-11-14 06:00:00  3.280740e+08  2420.250000    81.73000
# 50%              2013-09-24 12:00:00  5.566097e+08  5184.000000   154.06000
# 75%              2015-07-03 00:00:00  7.696945e+08  7536.750000   421.89000
# max              2017-07-26 00:00:00  9.955298e+08  9998.000000   668.27000
# std                              NaN  2.571334e+08  2901.375317   216.02106
#
#          Unit Cost  Total Revenue    Total Cost  Total Profit
# count  1000.000000   1.000000e+03  1.000000e+03  1.000000e+03
# mean    184.965110   1.327322e+06  9.361192e+05  3.912026e+05
# min       6.920000   2.043250e+03  1.416750e+03  5.326100e+02
# ...

# %% [markdown]
# # Numerical Analysis and Visualisation
#
# Analyse the Unit_Cost

# %%
sales['Unit Cost'].describe()
# Out:
# count    1000.000000
# mean      184.965110
# std       175.289311
# min         6.920000
# 25%        56.670000
# 50%        97.440000
# 75%       263.330000
# max       524.960000
# Name: Unit Cost, dtype: float64

# %%
sales['Unit Cost'].mean()
# Out:
# 184.96511

# %%
sales['Unit Cost'].median()
# Out:
# 97.44

# %%
sales['Unit Cost'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %%
sales['Unit Cost'].plot(kind='density', figsize=(14,6))
# Out:
# <Axes: ylabel='Density'>

# %%
ax = sales['Unit Cost'].plot(kind='density', figsize=(14,6))
ax.axvline(sales['Unit Cost'].mean(), color='red')
ax.axvline(sales['Unit Cost'].median(), color='green')

# %%
ax = sales['Unit Cost'].plot(kind='hist', figsize=(14,6))
ax.set_ylabel('Number of Sales')
ax.set_xlabel('Rands')
# Out:
# Text(0.5, 0, 'Rands')

# %% [markdown]
# # Categorical Analysis and Visualisation
#
# Analyse the Item Type

# %%
sales.head()

# %%
sales['Item Type'].value_counts()
# Out:
# Item Type
# Beverages          101
# Vegetables          97
# Office Supplies     89
# Baby Food           87
# Personal Care       87
# Snacks              82
# Cereal              79
# Clothes             78
# Meat                78
# Household           77
# Cosmetics           75
# Fruits              70
# Name: count, dtype: int64

# %%
sales['Item Type'].value_counts().plot(kind='pie', figsize=(10,10))
# Out:
# <Axes: ylabel='count'>

# %%
ax = sales['Item Type'].value_counts().plot(kind='bar', figsize=(14,6))
ax.set_ylabel('Number of Sales')
# Out:
# Text(0, 0.5, 'Number of Sales')

# %% [markdown]
# # Relationship Between the Columns?

# %%
#corr = sales.corr()
corr = sales.select_dtypes(include='number').corr()
corr
# Out:
#                Order ID  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# Order ID       1.000000    0.010266   -0.033436  -0.035550      -0.022079
# Units Sold     0.010266    1.000000    0.004212   0.002574       0.527945
# Unit Price    -0.033436    0.004212    1.000000   0.986735       0.730752
# Unit Cost     -0.035550    0.002574    0.986735   1.000000       0.717999
# Total Revenue -0.022079    0.527945    0.730752   0.717999       1.000000
# Total Cost    -0.025629    0.479713    0.745538   0.753678       0.987779
# Total Profit  -0.007886    0.591957    0.572235   0.498156       0.881429
#
#                Total Cost  Total Profit
# Order ID        -0.025629     -0.007886
# Units Sold       0.479713      0.591957
# Unit Price       0.745538      0.572235
# Unit Cost        0.753678      0.498156
# Total Revenue    0.987779      0.881429
# Total Cost       1.000000      0.797041
# Total Profit     0.797041      1.000000

# %%
fig = plt.figure(figsize=(8,8))
plt.matshow(corr, cmap='RdBu', fignum=fig.number)
plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical');
plt.yticks(range(len(corr.columns)), corr.columns);

# %%
sales.plot(kind='scatter', x='Units Sold', y='Total Profit', figsize=(6,6))
# Out:
# <Axes: xlabel='Units Sold', ylabel='Total Profit'>

# %%
sales.plot(kind='scatter', x='Total Revenue', y='Total Profit', figsize=(6,6))
# Out:
# <Axes: xlabel='Total Revenue', ylabel='Total Profit'>

# %%
ax = sales[['Total Profit', 'Item Type']].boxplot(by='Item Type', figsize=(16,6))
ax.set_ylabel('Profit')
# Out:
# Text(0, 0.5, 'Profit')

# %%
boxplot_cols = ['Units Sold',	'Unit Price', 	'Unit Cost',	'Total Revenue',	'Total Cost',	'Total Profit']

sales[boxplot_cols].plot(kind='box', subplots=True, layout=(2,3), figsize=(14,8))
# Out:
# Units Sold          Axes(0.125,0.53;0.227941x0.35)
# Unit Price       Axes(0.398529,0.53;0.227941x0.35)
# Unit Cost        Axes(0.672059,0.53;0.227941x0.35)
# Total Revenue       Axes(0.125,0.11;0.227941x0.35)
# Total Cost       Axes(0.398529,0.11;0.227941x0.35)
# Total Profit     Axes(0.672059,0.11;0.227941x0.35)
# dtype: object

# %% [markdown]
# # Column Wrangling
#
# ## Creating new columns or Modifying existing ones.
